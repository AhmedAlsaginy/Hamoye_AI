# %%
import pandas as pd

# %%
df=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding='latin-1')

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
gk=df.groupby("Item")

# %%
gk

# %%
gk.first()
# Out:
#                      Area Code     Area  Item Code  Element Code  \
# Item
# Alcohol, Non-Food            4  Algeria       2659          5511
# Alcoholic Beverages          4  Algeria       2924          5511
# Animal Products              4  Algeria       2941           664
# Animal fats                  4  Algeria       2946          5511
# Apples and products          4  Algeria       2617          5511
# ...                        ...      ...        ...           ...
# Vegetables, Other            4  Algeria       2605          5511
# Vegetal Products             4  Algeria       2903           664
# Wheat and products           4  Algeria       2511          5511
# Wine                         4  Algeria       2655          5511
# Yams                         4  Algeria       2535          5911
#
#                                            Element             Unit   Y2014  \
# Item
# Alcohol, Non-Food                       Production      1000 tonnes     0.0
# ...

# %%
gk.get_group('Animal fats')
# Out:
#        Area Code      Area  Item Code         Item  Element Code  \
# 1057           4   Algeria       2946  Animal fats          5511
# 1058           4   Algeria       2946  Animal fats          5611
# 1059           4   Algeria       2946  Animal fats          5072
# 1060           4   Algeria       2946  Animal fats          5911
# 1061           4   Algeria       2946  Animal fats          5301
# ...          ...       ...        ...          ...           ...
# 60697        181  Zimbabwe       2946  Animal fats          5142
# 60698        181  Zimbabwe       2946  Animal fats           645
# 60699        181  Zimbabwe       2946  Animal fats           664
# 60700        181  Zimbabwe       2946  Animal fats           674
# 60701        181  Zimbabwe       2946  Animal fats           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 1057                               Production      1000 tonnes  18.00  17.00
# ...

# %%
m=gk.get_group('Animal fats')

# %%
m['Y2014'].sum()
# Out:
# 209460.54

# %%
m['Y2017'].sum()
# Out:
# 269617.53

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 7614

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
gkk=df.groupby('Element')

# %%
gkk

# %%
mm=gkk.get_group('Import Quantity')

# %%
mm['Y2014'].sum()
# Out:
# 274144.48

# %%
mm['Y2015'].sum()
# Out:
# 267018.45999999996

# %%
mm['Y2016'].sum()
# Out:
# 286582.78

# %%
mm['Y2017'].sum()
# Out:
# 294559.09

# %%
mmm=gkk.get_group('Production')

# %%
mmm['Y2014'].sum()
# Out:
# 1931287.75

# %%
df1=df[["Y2018","Element"]]

# %%
gm=df1.groupby("Element")

# %%
gm.sum()
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Total Population - Both sexes           1140605.00
# ...

# %%
max(gm.sum())
# Out:
# 'Y2018'

# %%
df11=df[["Area","Y2018","Element"]]

# %%
gm1=df11.groupby(['Area','Element'])

# %%
gm1.sum().head(200)
# Out:
#                                                      Y2018
# Area          Element
# Algeria       Domestic supply quantity            90023.42
#               Export Quantity                       811.54
#               Fat supply quantity (g/capita/day)    309.09
#               Feed                                10668.00
#               Food                                63736.33
# ...                                                    ...
# Côte d'Ivoire Stock Variation                      3071.00
#               Total Population - Both sexes       25069.00
# Djibouti      Domestic supply quantity             2760.96
#               Export Quantity                      1084.00
#               Fat supply quantity (g/capita/day)    247.43
#
# [200 rows x 1 columns]

# %%
pd.unique(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11452/656283662.py in <module>
# ----> 1 pd.unique(df)
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     419     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     420     """
# --> 421     values = _ensure_arraylike(values)
#     422
#     423     if is_extension_array_dtype(values):
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pandas\core\algorithms.py in _ensure_arraylike(values)
#     235             if isinstance(values, tuple):
#     236                 values = list(values)
# --> 237             values = construct_1d_object_array_from_listlike(values)
#     238         else:
#     239             values = np.asarray(values)
#
# ...

# %%
df.Area.unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "Côte d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)
